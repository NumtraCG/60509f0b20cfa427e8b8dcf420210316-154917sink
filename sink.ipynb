# %% [markdown]
# ***GENERATED CODE FOR sink PIPELINE.***

# %% [markdown]
# ***DON'T EDIT THIS CODE.***

# %% [markdown]
# ***CONNECTOR FUNCTIONS TO READ DATA.***

# %% [markdown]
# ***CONNECTOR FUNCTIONS TO WRITE DATA.***

# %%
import datetime
import requests
import datetime
import logging
import warnings
warnings.filterwarnings('ignore')
logging.basicConfig(format='%(levelname)s:%(message)s', level=logging.INFO)


class NumtraConnector:

    def put(inStages, inStagesData, stageId, spark, config):
        path = eval(config)['server_url']
        baseType = eval(config)['baseType']
        results_url = eval(config)['results_url']
        server = eval(config)['server']
        originalfile = eval(config)['orignalKey']
        eval(config)['pathOnly']
        filename = eval(config)['filename']
        eval(config)['ser']
        eval(config)['user']
        eval(config)['password']
        eval(config)['authSource']
        eval(config)['user_id']
        eval(config)['parent_id']
        eval(config)['project_id']
        time = str(int(datetime.datetime.now().timestamp()))

        inStagesData[inStages[0]]

        print(path)
        print(baseType)
        print(results_url)
        print(server)
        print(originalfile)
        print(filename)

        args = {
            'url': path,
            'baseType': baseType,
            'originalfile': originalfile,
            'filename': time + filename
        }

        response = requests.post(results_url, args)
        return response

# %% [markdown]
# ***READING DATAFRAME***

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

#%run sinkHooks.ipynb
try:
	#sourcePreExecutionHook()

	bostontest = DBFSConnector.fetch(spark, "{'url': '/FileStore/platform/uploadedSourceFiles/1615897366602_BostonTest.csv', 'file_type': 'Delimeted', 'delimiter': ',', 'is_header': 'Use Header Line', 'FilePath': '/Numtra Platsink/BostonTest.csv', 'filename': '1615897366602_BostonTest.csv', 'viewFileName': 'BostonTest.csv', 'results_url': 'http://40.113.247.47:4040/api/read/hdfs'}")
	#sourcePostExecutionHook(bostontest)

except Exception as ex: 
	logging.error(ex)

# %% [markdown]
# ***WRITING DATAFRAME***

# %%
#%run sinkHooks.ipynb
try:
	#sinkPreExecutionHook()

	numtraplatsink = NumtraConnector.fetch(spark, "{'samplefile': '/FileStore/platform/sampleData/6050ae6bfc41a043c11bd5b0/part-00000-tid-687050695225269147-2f37a85c-2545-4127-a67e-aeafc68513a9-9-1-c000.csv', 'samplecount': 19, 'originalcount': 19, 'orignalKey': '/FileStore/platform/uploadedSourceFiles/1615897366602_BostonTest.csv', 'pathOnly': '/Numtra Platsink', 'project_id': '60509efb20cfa427e8b8dcf3', 'parent_id': '60509efb20cfa427e8b8dcf3', 'original_schema': [{'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5c1', 'field': 'CRIM', 'alias': 'CRIM', 'position': '1', 'type': 'CRIM'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5c2', 'field': 'ZN', 'alias': 'ZN', 'position': '2', 'type': 'ZN'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5c3', 'field': 'INDUS', 'alias': 'INDUS', 'position': '3', 'type': 'INDUS'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5c4', 'field': 'CHAS', 'alias': 'CHAS', 'position': '4', 'type': 'CHAS'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5c5', 'field': 'NOX', 'alias': 'NOX', 'position': '5', 'type': 'NOX'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5c6', 'field': 'RM', 'alias': 'RM', 'position': '6', 'type': 'RM'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5c7', 'field': 'AGE', 'alias': 'AGE', 'position': '7', 'type': 'AGE'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5c8', 'field': 'DIS', 'alias': 'DIS', 'position': '8', 'type': 'DIS'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5c9', 'field': 'RAD', 'alias': 'RAD', 'position': '9', 'type': 'RAD'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5ca', 'field': 'TAX', 'alias': 'TAX', 'position': '10', 'type': 'TAX'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5cb', 'field': 'PTRATIO', 'alias': 'PTRATIO', 'position': '11', 'type': 'PTRATIO'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5cc', 'field': 'B', 'alias': 'B', 'position': '12', 'type': 'B'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5cd', 'field': 'LSTAT', 'alias': 'LSTAT', 'position': '13', 'type': 'LSTAT'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5ce', 'field': 'MEDV', 'alias': 'MEDV', 'position': '14', 'type': 'MEDV'}], 'actual_schema': [{'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5b3', 'field': 'CRIM', 'alias': 'CRIM', 'position': '1', 'type': 'CRIM'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5b4', 'field': 'ZN', 'alias': 'ZN', 'position': '2', 'type': 'ZN'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5b5', 'field': 'INDUS', 'alias': 'INDUS', 'position': '3', 'type': 'INDUS'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5b6', 'field': 'CHAS', 'alias': 'CHAS', 'position': '4', 'type': 'CHAS'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5b7', 'field': 'NOX', 'alias': 'NOX', 'position': '5', 'type': 'NOX'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5b8', 'field': 'RM', 'alias': 'RM', 'position': '6', 'type': 'RM'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5b9', 'field': 'AGE', 'alias': 'AGE', 'position': '7', 'type': 'AGE'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5ba', 'field': 'DIS', 'alias': 'DIS', 'position': '8', 'type': 'DIS'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5bb', 'field': 'RAD', 'alias': 'RAD', 'position': '9', 'type': 'RAD'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5bc', 'field': 'TAX', 'alias': 'TAX', 'position': '10', 'type': 'TAX'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5bd', 'field': 'PTRATIO', 'alias': 'PTRATIO', 'position': '11', 'type': 'PTRATIO'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5be', 'field': 'B', 'alias': 'B', 'position': '12', 'type': 'B'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5bf', 'field': 'LSTAT', 'alias': 'LSTAT', 'position': '13', 'type': 'LSTAT'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6050bf08fc41a043c11bd5c0', 'field': 'MEDV', 'alias': 'MEDV', 'position': '14', 'type': 'MEDV'}], 'server': 'https://wshstaging.numtra.com', 'server_url': '/numtraplatform/NumtraPlatformV2/uploads/platform/', 'delimiter': ',', 'file_type': 'Delimeted', 'filename': 'testFile.csv', 'is_header': 'Use Header Line', 'results_url': 'http://40.113.247.47:4040/api/read/hdfs'}")

except Exception as ex: 
	logging.error(ex)
